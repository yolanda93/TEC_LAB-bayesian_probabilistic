# %% [markdown]
# ## Predicting uncertainty with (deep) neural networks

# %% [markdown]
# **Experiment**: Keras implementation of the original experiment (implemented in Pytorch) using two different tensors (y and sigma) for target

# %% [markdown]
# **NOTE**: This notebook has been adapted to ease its comprenhesion : https://github.com/sthorn/deep-learning-explorations/blob/master/predicting-uncertainty.ipynb*

# %% [markdown]
# ### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
import statistics as stat
import tensorflow as tf

# %matplotlib inline

# %% [markdown]
# ### Generate some random data

# %%
# Generate some linearly related data
np.random.seed(2019)

n_samples = 10000
x = np.random.random(n_samples)

sin_ = 0.4 * np.sin(x*4*np.pi)
eps = np.random.normal(scale=1.0, size=n_samples) * sin_ # noise
y_1 = 2*x + 1 
y = y_1 + eps # linear data with noise

# %% [markdown]
# ### Prepare data for training

# %%
# Add in column of dummy zeros to represent sigma 
sigma = np.zeros(y.size)
y = np.stack([y, sigma], axis=1)

# %%
# Reshape x for PyTorch
#x = x.reshape(10000, 1)
x = x.reshape(x.size, 1)

# %%
# Split into training and validation sets
n_validation = 500
x_val, x = x[:n_validation], x[n_validation:]
y_val, y = y[:n_validation], y[n_validation:]

# %%
# Plot the data
plt.figure(figsize=(14,6))
plt.title('Training and validation sets')
plt.plot(x, y, '.', color= 'green')
plt.plot(x_val, y_val, '.', color='purple')
plt.xlabel(r'$x$');
plt.ylabel(r'$y$');

# %%
# Convert x and y to PyTorch Variables on the GPU
x_t = tf.convert_to_tensor(x, np.float32)
y_t = tf.convert_to_tensor(y[:,[0]], np.float32)
sigma_t = tf.convert_to_tensor(y[:,[1]], np.float32)

# %%
# Check shape ok for PyTorch - x should be (n x 1), y (n x 2)
x_t.shape, y_t.shape, sigma_t.shape
# Out:
# (TensorShape([Dimension(9500), Dimension(1)]),
#  TensorShape([Dimension(9500), Dimension(1)]),
#  TensorShape([Dimension(9500), Dimension(1)]))

# %%
y_t[:,0]
# Out:
# <tf.Tensor 'strided_slice_2:0' shape=(9500,) dtype=float32>

# %% [markdown]
# ## Experiment

# %% [markdown]
# ### Create a simple network

# %%
# Create a simple two-layer network with one input (x) and two outputs (y, sigma)
n_inputs = 1
n_outputs = 2
n_hidden = 1000

def get_model01():
    in_x = tf.keras.Input(
        shape=(1,),
        name="x"
    )
    f1 = tf.keras.layers.Dense(
        n_hidden,
        name="hidden",
        activation=tf.keras.activations.relu
    )(in_x)
    out_y = tf.keras.layers.Dense(
        1,
        name="y",
        activation=tf.keras.activations.linear
    )(f1)
    out_var = tf.keras.layers.Dense(
        1,
        name="sigma",
        activation=tf.keras.activations.linear
    )(f1)
    return tf.keras.Model(inputs=[in_x], outputs=[out_y, out_var], name="model01")

# %%
model_2 = get_model01()
model_2.summary()
# Out:
# Model: "model01"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# x (InputLayer)                  [(None, 1)]          0
# __________________________________________________________________________________________________
# hidden (Dense)                  (None, 1000)         2000        x[0][0]
# __________________________________________________________________________________________________
# y (Dense)                       (None, 1)            1001        hidden[0][0]
# __________________________________________________________________________________________________
# sigma (Dense)                   (None, 1)            1001        hidden[0][0]
# ==================================================================================================
# Total params: 4,002
# Trainable params: 4,002
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Custom loss function
# This is where the magic happens.

# %%
from keras import losses

def sigma_loss_error(y_true, y_pred):
    # Estimate target value for variance (sigma^2) with (y_pred - y)**2
    #
    diff_var = tf.Variable((y_pred - y_true)**2)
    #y_true = diff_var  # compute variance <------------------- HERE is the problem !! Cannot update the variable...
    #with tf.control_dependencies([y_true]):
    return  losses.mean_squared_error(y_pred, y_true)

# %%
lossWeights={'y':0.5,
          'sigma':0.5  
        }
custom_losses ={'y':'mean_squared_error',
          'sigma':sigma_loss_error    
        }

model_2.compile(loss=custom_losses, loss_weights= lossWeights, target_tensors=[y_t, sigma_t], optimizer='adam')

# %% [markdown]
# ### Training loop
# We train this simple model with batch size equal to the whole dataset.

# %%
steps_=50
n_epochs = int(10000/steps_)
model_2.fit(x_t, epochs=n_epochs, batch_size=32, verbose=1, steps_per_epoch=steps_)
# Out:
# Epoch 1/200
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0411 - y_loss: 0.0822 - sigma_loss: 1.8822e-05
# Epoch 2/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 2.3085e-07
# Epoch 3/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 4.1110e-09
# Epoch 4/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 2.4441e-09
# Epoch 5/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 2.3383e-09
# Epoch 6/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 2.2529e-09
# Epoch 7/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 2.1626e-09
# Epoch 8/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 2.0888e-09
# Epoch 9/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 2.2863e-09
# Epoch 10/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 2.2643e-09
# Epoch 11/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 2.2808e-09
# Epoch 12/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 2.1191e-09
# Epoch 13/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 2.1677e-09
# Epoch 14/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 2.3884e-09
# Epoch 15/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 2.8804e-09
# Epoch 16/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 1.3601e-06
# Epoch 17/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 1.8958e-07
# Epoch 18/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 1.5966e-06
# Epoch 19/200
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 8.3860e-08
# Epoch 20/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 1.1866e-06
# Epoch 21/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 7.3657e-08
# Epoch 22/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 1.1006e-06
# Epoch 23/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 3.8066e-08
# Epoch 24/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 1.0447e-06
# Epoch 25/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 1.5999e-08
# Epoch 26/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 1.3527e-06
# Epoch 27/200
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 5.1705e-08
# Epoch 28/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 1.4489e-08
# Epoch 29/200
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 2.2484e-06
# Epoch 30/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 5.3241e-08
# Epoch 31/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 7.3726e-07
# Epoch 32/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 1.9053e-08
# Epoch 33/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 2.6928e-06
# Epoch 34/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 3.3913e-07
# Epoch 35/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 4.1988e-09
# Epoch 36/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 7.0611e-09
# Epoch 37/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 1.7141e-06
# Epoch 38/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 5.4774e-07
# Epoch 39/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 6.7515e-09
# Epoch 40/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 4.5113e-07
# Epoch 41/200
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 2.4214e-06
# Epoch 42/200
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 1.8747e-08
# Epoch 43/200
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 7.1434e-09
# Epoch 44/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 1.4208e-06
# Epoch 45/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 1.0837e-06
# Epoch 46/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 5.2239e-08
# Epoch 47/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 1.9398e-07
# Epoch 48/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 1.4236e-06
# Epoch 49/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 1.7842e-07
# Epoch 50/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 4.2439e-07
# Epoch 51/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 1.5976e-06
# Epoch 52/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 4.0518e-08
# Epoch 53/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 2.0229e-06
# Epoch 54/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 5.7087e-08
# Epoch 55/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 3.2603e-08
# Epoch 56/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 5.0450e-07
# Epoch 57/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 8.4556e-07
# Epoch 58/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 4.5594e-07
# Epoch 59/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 2.0491e-06
# Epoch 60/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 3.1047e-07
# Epoch 61/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 3.7373e-08
# Epoch 62/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 5.7474e-08
# Epoch 63/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 2.9074e-06
# Epoch 64/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 3.0297e-08
# Epoch 65/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 2.3092e-09
# Epoch 66/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 4.7962e-09
# Epoch 67/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 2.7954e-06
# Epoch 68/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 9.9553e-08
# Epoch 69/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 7.3932e-09
# Epoch 70/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 2.6549e-09
# Epoch 71/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 2.7717e-06
# Epoch 72/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss:
200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 2.0288e-06
# Epoch 168/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 6.6200e-08
# Epoch 169/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 3.8046e-08
# Epoch 170/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 1.2771e-06
# Epoch 171/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 1.8126e-07
# Epoch 172/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 8.3319e-07
# Epoch 173/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 4.8558e-07
# Epoch 174/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 1.4584e-06
# Epoch 175/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 1.0298e-07
# Epoch 176/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 3.8491e-07
# Epoch 177/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 1.4747e-06
# Epoch 178/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 1.5638e-07
# Epoch 179/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 6.2770e-07
# Epoch 180/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 6.2802e-07
# Epoch 181/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 1.0152e-06
# Epoch 182/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 1.2608e-07
# Epoch 183/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 6.6915e-07
# Epoch 184/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 1.0428e-06
# Epoch 185/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 3.1753e-07
# Epoch 186/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 7.7640e-07
# Epoch 187/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 3.9598e-07
# Epoch 188/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 1.0275e-06
# Epoch 189/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 2.3175e-07
# Epoch 190/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 1.3669e-06
# Epoch 191/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 1.0969e-07
# Epoch 192/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 2.1163e-06
# Epoch 193/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 3.0175e-07
# Epoch 194/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 6.1212e-09
# Epoch 195/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 9.0271e-09
# Epoch 196/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 2.9025e-06
# Epoch 197/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 8.8762e-08
# Epoch 198/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 2.9825e-09
# Epoch 199/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 2.6391e-09
# Epoch 200/200
# 50/50 [==============================] - 1s 14ms/step - loss: 0.0411 - y_loss: 0.0821 - sigma_loss: 2.6418e-06

# %% [markdown]
# ### Get predictions for validation set

# %%
# Get predicted y and sigma for validation set
x_val_t =  tf.convert_to_tensor(x_val, np.float32)
pred_1 = model_2.predict(x_val_t, steps=1)

len(pred_1), x_val_t.shape

# %%
len(pred_1[1])
# Out:
# 500

# %%
# prediction of the response variables
y_pred_1 = pred_1[0]
sigma_pred_1 = pred_1[1]

# %% [markdown]
# ### Plot results

# %%
# Plot predictions and their errors
fig, ax1 = plt.subplots(figsize=(14,6))

ax1.plot(x, y[:,0], '.', alpha=0.4, color='pink')
ax1.plot(x_val, y_val[:,0], '.', color='blue')
ax1.plot(x_val, y_pred_1, '.', color='purple')
ax1.errorbar(x_val, y_pred_1, yerr=sigma_pred_1, fmt='.k');

ax1.set_xlabel(r'$x$');
ax1.set_ylabel(r'$y$');
ax1.set_title('Validation set predictions');
ax1.legend([r'Training', r'Validation', r'Prediction of y','Prediction of $\pm \sigma$'], loc='upper left', );
# Out:
# C:\Users\yolan\Anaconda3\envs\deep_learning_keras\lib\site-packages\ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Support for passing a (n, 1)-shaped error array to errorbar() is deprecated since Matplotlib 3.1 and will be removed in 3.3; pass a 1D array instead.
#   import sys

# %%
# Plot predictions and their errors
plt.figure(figsize=(14,6))
plt.errorbar(x_val, y_pred_1, yerr=sigma_pred_1, fmt='.');

# One standard-deviation envelope
xs = np.linspace(0.0, 1.0, 50)
err = 0.4*np.sin(xs*4*np.pi)
plt.fill_between(xs, 2*xs+1-err, 2*xs+1+err, facecolor='orange', alpha=0.5, edgecolor='none');
plt.xlabel(r'$x$');
plt.ylabel(r'$y$');
plt.title('Validation set predictions');
plt.legend([r'Original data $\pm \sigma$ envelope','Validation set predictions'], loc='upper left', );
# Out:
# C:\Users\yolan\Anaconda3\envs\deep_learning_keras\lib\site-packages\ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Support for passing a (n, 1)-shaped error array to errorbar() is deprecated since Matplotlib 3.1 and will be removed in 3.3; pass a 1D array instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
